# %% [markdown]
# # Lab 4 — Submission Setup, and Object Oriented Programming
#
# **This session (Friday 9/11) starts with getting submission working**, then moves to the
# exercises.
#
# Two halves:
#
# 1. **Setting up submission** — fork, clone, wire the remotes, commit, push. We do this together,
#    from scratch. You do not need to have done anything beforehand. **Lab 2 is due tonight and you
#    will submit it here.**
# 2. **The Object Oriented Programming exercises** — the lab itself, which uses the Lectures 8–9
#    material.
#
# `Labs/GitHub-Setup.pdf` is the written version of part 1, with a table of what to do when git
# complains. If you already have authentication working from Lab 3, part 1 will be quick.

# %% [markdown]
# ## Part 1 — Setting up submission (this session)
#
# Our course repository is public. The instructions here aim to have you setup a fork of the course repository. Unfortunately because you are forking a public repo, your fork will have to be public also.
#
# > **The same steps, in a document you can follow line by line, are in
# > `Labs/GitHub-Setup.pdf`.** It covers authentication, the WSL filesystem trap, git identity, the
# > remote setup below, the two errors everyone hits on their first push, and a table of what to do
# > when git complains. If you only read one thing, read that.
#
# You should be familiar with git from the first semester of this course. I assume that you all have github accounts and have setup things to be able to [push to github using ssh](https://docs.github.com/en/github/authenticating-to-github/connecting-to-github-with-ssh). The instructions here lead you to:
#
# We'll overview what you will do before going through step by step instructions.
#
# 1. Setup:
#     1. Fork the class repository. Some directions in [fork-a-repo](https://docs.github.com/en/github/getting-started-with-github/fork-a-repo).
#     1. Create a directory on your personal system where you will keep all course materials.
#     1. In that directory, clone your fork of the repository.
#     1. Using `git remote`, set the upstream to be the class repo, so you can pull from the class and push to your fork.
#
# 1. Submission:
#     1. Copy your solutions into the appropriate directory (e.g. into `Labs/Lab.2/`) and with appropriate filename `Lab.2.solution.ipynb`.
#     1. Commit / push your solutions.
#
# Below are step by step instructions with examples (including example directory naming convention). Feel free to modify things as you see fit.
#
# #### Setup
# You should only need to follow this instructions once. Here are some useful git commands:
#
# * Git help: `git help`
# * Git remote help: `git help remote`
# * Check remote status: `git remote -v`
# * Add a remote: `git remote add <stream name> <repo URL>`
# * Remove a remote: `git remote remove <stream name>`
#
# Steps:
# 1. In a browser, log into GitHub and navigate to the [course repository](https://github.com/UTA-DataScience/DATA3402.Fall.2026).
# 1. On the top right of the page, press the fork button to create a new fork into your own GitHub account.
# 1. After successful fork, you should find the browser showing your fork of the course repository. Use the green "Code" button to copy path to the repo into your the clipboard of your computer.
# 1. Open a shell on your personal computer.
# 1. If you have not done so already, create a new directory/folder where you will keep all course material to navigate to it. For example: `mkdir Data-3402` and `cd Data-3402`.
# 1. Clone your fork of the repository using `git clone` followed by the path you copied into your clipboard. (copy/paste)
# 1. Paste the URL to your fork in the worksheet for the TAs and instructors.
# 1. Now go into the directory of your clone (`cd DATA3402.Fall.2026`).
# 1. Type `git remote -v` to see the current setup for fetch and pull.
# 1. Note the URL you see. This should be the same as what you used for your clone for both push and fetch.
# 1. Delete the origin remote using `git remote remove origin`.
# 1. Add the course repo as your remote using `git remote add origin https://github.com/UTA-DataScience/DATA3402.Fall.2026.git`.
# 1. Change the push to point to your fork. This means you will need the URL to your clone we copied earlier and confirmed as the original origin. The command will look something like: `git remote set-url --push origin  https://github.com/XXXXXX/DATA3402.Fall.2026.git`, where XXXXX is your username on GitHub.
# 1. Note that if you setup everything correctly, you now should be able to do `git pull` to get updates from the course repo, and do `git push` to push your commits into your own fork.
#
# ### Submission
# These instructions outline how you submit files. Some useful commands:
# * To add a file to local repository: `git add <file>`.
# * To commit all changed files into local repository: `git commit -a -m "A message"`. You need to provide some comment when you commit.
# * To push the commited files from the local repository to GitHub: `git push`.
# * To get updates from GitHub: `git pull`.
#
# Steps:
# 1. To submit your labs, navigate to your clone of your fork of the course repository.
# 1. Use `git pull` to make sure you have the latest updates.
# 1. Make sure your copy of the lab your are working on is in the appropriate place in this clone. That means if you have the file elsewhere, copy it to the same directory in your clone of your fork.
# 1. Do this **as soon as you pull a new lab, before you write anything** — not just before submitting: copy it to a name we never handed out, e.g. `cp Lab.2.ipynb Lab.2.solution.ipynb`, and work only in the copy from then on. `git pull` only touches filenames it recognizes from the class repo, so a copy under a new name can never conflict with an update we push later, even mid-week. If you already started editing `Lab.2.ipynb` directly, copy it now and switch over.
# 1. Add any files you wish to submit into the repo. For example: `git add Labs/Lab.2/Lab.2.solution.ipynb`
# 1. Commit any changes: `git commit -a -m "Lab 2 updates"`
# 1. Push your changes: `git push`
# 1. Check on github website that your solutions have been properly submitted.
#
# Before you leave today's session, make sure your GitHub repo is set up. If you need to work further on your lab, navigate jupyter to the copy of the lab you just submitted and work there. Once done, repeat the commit and push commands to submit your updated solution.
#
# Note that lab 2 is due by midnight Friday 9/11/2026.
#
# ---
#
# ## Part 2 — Object Oriented Programming exercises
#
# The rest of this notebook is the lab itself. It uses the classes material from Lectures 8 and 9,
# so start it after those; the submission setup above is what we do in the session.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_num):
        self.max_num = max_num
        self.value = 0
    def increase(self):
        if sel.value < self.max_num:
            self.value += 1
        else:
            print("Error")
    def reset(self):
        self.value = 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_num):
        self.__max_num = max_num
        self.__value = 0
    def increase(self):
        if sel.__value < self.__max_num:
            self.__value += 1
        else:
            print("Error")
    def reset(self):
        self.__value = 0
    def check_counter(self):
        return self.__value
    def check_max(self):
        return self.__max_num
    def at_max(self):
        return self.__value == self.__max_num

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and provide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        self.__x = x
        self.__y = y
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the circle. Make all data members private and provide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your rectangle and circle classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y
class Rectangle(Shape):
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        super().__init__(x, y)
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
class circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        super().__init__(x, y)
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y
class Rectangle(Shape):
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        super().__init__(x, y)
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
class circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        super().__init__(x, y)
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius
class triangle(Shape):
    def __init__(self, s1, s2, s3, x, y):
        super().__init__(x, y)
        self.__s1 = s1
        self.__s2 = s2
        self.__s3 = s3
    def perimeter(self):
        return self.__s1 + self.__s2 + self.__s3
    def area(self):
        a = self.perimeter() / 2
        return math.sqrt(a * (a - self.__s1) * (a - self.__s2) * (a - self.__s3))
    def check_sides(self):
        return self.__s1
        return self.__s2
        return self.__s3

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the perimeter of the object.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y
    def perimeter_points(self, num_points = 16):
        raise NotImplementedError("Error")
class Rectangle(Shape):
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        super().__init__(x, y)
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
    def perimeter_points(self, num_points = 16):
        points = []
        total_p = self.perimeter()
        step = total_p / num_points
        for i in range(num_points):
            d = i * step
            if d < self.__w:
                px, py = self.__x + d, self.__y
            elif d < self.__w + self.__l:
                px, py = self.__x + self.__width, self.__y + (d - self.__w)
            elif d < 2 * self.__w + self.__l:
                px, py = (self.__x + self.__w - (d - self.__w - self.__l), self.__y + self.__l,)
            else:
                px, py = self.__x, self.__y + self.__l - (d - 2 * self.__w - self.__l)
            points.append((round(px, 4), round(py, 4)))
        return points
class circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        super().__init__(x, y)
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius
    def perimeter_points(self, num_points = 16):
        points = []
        for i in range(num_points):
            angle = 2 * math.pi * i / num_points
            px = self.__x + self.__radius * math.cos(angle)
            py = self.__y + self.__radius * mathsin(angle)
            points.append((round(px, 4), round(py, 4)))
        return points
class triangle(Shape):
    def __init__(self, s1, s2, s3, x, y):
        super().__init__(x, y)
        self.__s1 = s1
        self.__s2 = s2
        self.__s3 = s3
    def perimeter(self):
        return self.__s1 + self.__s2 + self.__s3
    def area(self):
        a = self.perimeter() / 2
        return math.sqrt(a * (a - self.__s1) * (a - self.__s2) * (a - self.__s3))
    def check_sides(self):
        return self.__s1
        return self.__s2
        return self.__s3
    def perimeter_points(self, num_points = 16):
        cos_A = (self.__s1 ** 2 + self.__s3 ** 2 - self.__2 ** 2) / (2 * self.__s1 * self.__s3)
        sin_A = math.sqrt(max(0, 1 - cos_A **2))
        v0 = (self._x, self._y)
        v1 = (self._x + self.__s1, self._y)
        v2 = (self._x + self.__s3 * cos_A, self._y + self.__s3 * sin_A)
        total_p = self.perimeter()
        step = total_p / num_points
        points = []
        for i in range(num_points):
            d = i *step
            if d < self.__s1:
                t = d / self.__s1
                px = v0[0] + t * (v1[0] - v0[0])
                py = v0[1] + t * (v1[1] - v0[1])
            elif d < self.__s1 + self.__s2:
                t = (d - self.__s1) / self.__s2
                px = v1[0] + t * (v2[0] - v1[0])
                py = v1[1] + t * (v2[1] - v1[1])
            else:
                t = (d - self.__s1 - self.__s2) / self.__s3
                px = v2[0] + t * (v0[0] - v2[0])
                py = v2[1] + t * (v0[1] - v2[1])
            points.append((round(px, 4), round(py, 4)))
        return points

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y
    def perimeter_points(self, num_points = 16):
        raise NotImplementedError("Error")
    def is_inside(self, x, y):
        raise NotImplementedError("Error")
class Rectangle(Shape):
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        super().__init__(x, y)
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
    def perimeter_points(self, num_points = 16):
        points = []
        total_p = self.perimeter()
        step = total_p / num_points
        for i in range(num_points):
            d = i * step
            if d < self.__w:
                px, py = self.__x + d, self.__y
            elif d < self.__w + self.__l:
                px, py = self.__x + self.__width, self.__y + (d - self.__w)
            elif d < 2 * self.__w + self.__lenght:
                px, py = (self.__x + self.__width - (d - self.__width - self.__lenght), self.__y + self.__l,)
            else:
                px, py = self.__x, self.__y + self.__lenght - (d - 2 * self.__width - self.__lenght)
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        in_x = self._x <= x <= (self._x + self.__width)
        in_y = self._y <= y <= (self._y + self.__lenght)
        return in_x
        return in_y
class circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        super().__init__(x, y)
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius
    def perimeter_points(self, num_points = 16):
        points = []
        for i in range(num_points):
            angle = 2 * math.pi * i / num_points
            px = self.__x + self.__radius * math.cos(angle)
            py = self.__y + self.__radius * mathsin(angle)
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        distance = math.sqrt((x - self._x) ** 2 + (y - self._y) ** 2)
        return distance <= self.__radius
class triangle(Shape):
    def __init__(self, s1, s2, s3, x, y):
        super().__init__(x, y)
        self.__s1 = s1
        self.__s2 = s2
        self.__s3 = s3
    def perimeter(self):
        return self.__s1 + self.__s2 + self.__s3
    def area(self):
        a = self.perimeter() / 2
        return math.sqrt(a * (a - self.__s1) * (a - self.__s2) * (a - self.__s3))
    def check_sides(self):
        return self.__s1
        return self.__s2
        return self.__s3
    def perimeter_points(self, num_points = 16):
        cos_A = (self.__s1 ** 2 + self.__s3 ** 2 - self.__2 ** 2) / (2 * self.__s1 * self.__s3)
        sin_A = math.sqrt(max(0, 1 - cos_A **2))
        v0 = (self._x, self._y)
        v1 = (self._x + self.__s1, self._y)
        v2 = (self._x + self.__s3 * cos_A, self._y + self.__s3 * sin_A)
        total_p = self.perimeter()
        step = total_p / num_points
        points = []
        for i in range(num_points):
            d = i *step
            if d < self.__s1:
                t = d / self.__s1
                px = v0[0] + t * (v1[0] - v0[0])
                py = v0[1] + t * (v1[1] - v0[1])
            elif d < self.__s1 + self.__s2:
                t = (d - self.__s1) / self.__s2
                px = v1[0] + t * (v2[0] - v1[0])
                py = v1[1] + t * (v2[1] - v1[1])
            else:
                t = (d - self.__s1 - self.__s2) / self.__s3
                px = v2[0] + t * (v0[0] - v2[0])
                py = v2[1] + t * (v0[1] - v2[1])
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        cos_A = (self.__s1**2 + self.__s3**2 - self.__s2**2) / (2 * self.__s1 * self.__s3)
        sin_A = math.sqrt(max(0, 1 - cos_A**2))
        v0 = (self._x, self._y)
        v1 = (self._x + self.__s1, self._y)
        v2 = (self._x + self.__s3 * cos_A, self._y + self.__s3 * sin_A)
        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])
        p = (x, y)
        d1 = sign(p, v0, v1)
        d2 = sign(p, v1, v2)
        d3 = sign(p, v2, v0)
        neg = (d1 < 0) or (d2 < 0) or (d3 < 0)
        pos = (d1 > 0) or (d2 > 0) or (d3 > 0)
        return not (neg and pos)

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    def check_x(self):
        return self.__x
    def check_y(self):
        return self.__y
    def perimeter_points(self, num_points = 16):
        raise NotImplementedError("Error")
    def is_inside(self, x, y):
        raise NotImplementedError("Error")
    def overlaps(self, other):
        for px, py in self.perimeter_points(num_points = 16):
            if other.is_inside(px, py):
                return True
        for px, py in other.Perimeter_points(num_points = 16):
            if self.is_inside(px, py):
                return True
        if self.is_inside(other._x, other._y) or other.is_inside(self._x, self._y):
            return True
        return False
class Rectangle(Shape):
    def __init__(self, lenght, width, x, y):
        self.__lenght = lenght
        self.__width = width
        super().__init__(x, y)
    def area(self):
        return self.__lenght * self.__width
    def perimeter(self):
        return (2 * self.__lenght) + (2 * self.__width)
    def check_l(self):
        return self.__lenght
    def check_w(self):
        return self.__width
    def perimeter_points(self, num_points = 16):
        points = []
        total_p = self.perimeter()
        step = total_p / num_points
        for i in range(num_points):
            d = i * step
            if d < self.__w:
                px, py = self.__x + d, self.__y
            elif d < self.__w + self.__l:
                px, py = self.__x + self.__width, self.__y + (d - self.__w)
            elif d < 2 * self.__w + self.__lenght:
                px, py = (self.__x + self.__width - (d - self.__width - self.__lenght), self.__y + self.__l,)
            else:
                px, py = self.__x, self.__y + self.__lenght - (d - 2 * self.__width - self.__lenght)
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        in_x = self._x <= x <= (self._x + self.__width)
        in_y = self._y <= y <= (self._y + self.__lenght)
        return in_x
        return in_y
class circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        super().__init__(x, y)
    def area(self):
        return math.pi * (self.__radius ** 2)
    def perimeter(self):
        return 2 * math.pi * self.__radius
    def check_radius(self):
        return self.__radius
    def perimeter_points(self, num_points = 16):
        points = []
        for i in range(num_points):
            angle = 2 * math.pi * i / num_points
            px = self.__x + self.__radius * math.cos(angle)
            py = self.__y + self.__radius * mathsin(angle)
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        distance = math.sqrt((x - self._x) ** 2 + (y - self._y) ** 2)
        return distance <= self.__radius
class triangle(Shape):
    def __init__(self, s1, s2, s3, x, y):
        super().__init__(x, y)
        self.__s1 = s1
        self.__s2 = s2
        self.__s3 = s3
    def perimeter(self):
        return self.__s1 + self.__s2 + self.__s3
    def area(self):
        a = self.perimeter() / 2
        return math.sqrt(a * (a - self.__s1) * (a - self.__s2) * (a - self.__s3))
    def check_sides(self):
        return self.__s1
        return self.__s2
        return self.__s3
    def perimeter_points(self, num_points = 16):
        cos_A = (self.__s1 ** 2 + self.__s3 ** 2 - self.__2 ** 2) / (2 * self.__s1 * self.__s3)
        sin_A = math.sqrt(max(0, 1 - cos_A **2))
        v0 = (self._x, self._y)
        v1 = (self._x + self.__s1, self._y)
        v2 = (self._x + self.__s3 * cos_A, self._y + self.__s3 * sin_A)
        total_p = self.perimeter()
        step = total_p / num_points
        points = []
        for i in range(num_points):
            d = i *step
            if d < self.__s1:
                t = d / self.__s1
                px = v0[0] + t * (v1[0] - v0[0])
                py = v0[1] + t * (v1[1] - v0[1])
            elif d < self.__s1 + self.__s2:
                t = (d - self.__s1) / self.__s2
                px = v1[0] + t * (v2[0] - v1[0])
                py = v1[1] + t * (v2[1] - v1[1])
            else:
                t = (d - self.__s1 - self.__s2) / self.__s3
                px = v2[0] + t * (v0[0] - v2[0])
                py = v2[1] + t * (v0[1] - v2[1])
            points.append((round(px, 4), round(py, 4)))
        return points
    def is_inside(self, x, y):
        cos_A = (self.__s1**2 + self.__s3**2 - self.__s2**2) / (2 * self.__s1 * self.__s3)
        sin_A = math.sqrt(max(0, 1 - cos_A**2))
        v0 = (self._x, self._y)
        v1 = (self._x + self.__s1, self._y)
        v2 = (self._x + self.__s3 * cos_A, self._y + self.__s3 * sin_A)
        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])
        p = (x, y)
        d1 = sign(p, v0, v1)
        d2 = sign(p, v1, v2)
        d3 = sign(p, v2, v0)
        neg = (d1 < 0) or (d2 < 0) or (d3 < 0)
        pos = (d1 > 0) or (d2 > 0) or (d3 > 0)
        return not (neg and pos)

# %% [markdown]
# 10. Copy the `Canvas` class from lecture into a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstrate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
